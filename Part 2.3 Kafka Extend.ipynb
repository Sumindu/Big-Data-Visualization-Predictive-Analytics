# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\users\user\anaconda3\lib\site-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\user\anaconda3\lib\site-packages (from pyspark) (0.10.9.7)

# %%
from confluent_kafka import Consumer, KafkaException, KafkaError
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
import json

consumer_conf = {
    'bootstrap.servers': 'localhost:9092',  # Kafka broker address
    'group.id': 'joke-consumer',            # Consumer group ID
    'auto.offset.reset': 'earliest'         # Start from the earliest message
}

consumer = Consumer(consumer_conf)
topic = 'test1-topic'  # Replace with your Kafka topic name
consumer.subscribe([topic])

spark = SparkSession.builder.appName("JokeConsumer").getOrCreate()

data_list = []

def process_message(message):
    try:
        data = json.loads(message)
        data_list.append((
            data['type'],
            len(data['setup']),
            len(data['punchline']),
            data['id']
        ))
    except (KeyError, json.JSONDecodeError):
        print("Error processing message: Invalid JSON structure")

def consume_messages():
    print("Listening for messages...")
    try:
        while True:
            msg = consumer.poll(timeout=1.0)
            if msg is None:
                continue
            if msg.error():
                if msg.error().code() == KafkaError._PARTITION_EOF:
                    print(f"End of partition reached: {msg.topic()} [{msg.partition()}] at offset {msg.offset()}")
                else:
                    print(f"Error: {msg.error()}")
            else:
                print(f"Received message: {msg.value().decode('utf-8')}")
                process_message(msg.value().decode('utf-8'))
    except KeyboardInterrupt:
        print("\nConsumer interrupted. Shutting down...")
        if data_list:
            df = spark.createDataFrame(data_list, ["type", "setup_length", "punchline_length", "id"])
            df.show(truncate=False)
            print("\nDescriptive Statistics:")
            df.describe("setup_length", "punchline_length", "id").show()

            print("\nAdditional Statistics:")
            stats = df.agg(
                F.avg("setup_length").alias("avg_setup_length"),
                F.avg("punchline_length").alias("avg_punchline_length"),
                F.stddev("setup_length").alias("stddev_setup_length"),
                F.stddev("punchline_length").alias("stddev_punchline_length")
            )
            stats.show()
        else:
            print("No data to analyze.")
    finally:
        consumer.close()
        print("Consumer closed.")

consume_messages()
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Received message: {"type": "general", "setup": "What do you call a monkey in a mine field?", "punchline": "A babooooom!", "id": 210}
# Received message: {"type": "general", "setup": "What biscuit does a short person like?", "punchline": "Shortbread. ", "id": 155}
# Received message: {"type": "general", "setup": "Why do crabs never give to charity?", "punchline": "Because they\u2019re shellfish.", "id": 346}
# Received message: {"type": "general", "setup": "Did you hear about the runner who was criticized?", "punchline": "He just took it in stride", "id": 93}
# Received message: {"type": "general", "setup": "What did Michael Jackson name his denim store?", "punchline": "Billy Jeans!", "id": 159}
# Received message: {"type": "general", "setup": "How good are you at Power Point?", "punchline": "I Excel at it.", "id": 128}
# Received message: {"type": "general", "setup": "What did the pirate say on his 80th birthday?", "punchline": "Aye Matey!", "id": 181}
# Received message: {"type": "programming", "setup": "Where did the API go to eat?", "punchline": "To the RESTaurant.", "id": 390}
# Received message: {"type": "general", "setup": "How was the snow globe feeling after the storm?", "punchline": "A little shaken.", "id": 145}
# Received message: {"type": "general", "setup": "How many kids with ADD does it take to change a lightbulb?", "punchline": "Let's go ride bikes!", "id": 140}
# Received message: {"type": "general", "setup": "How many bones are in the human hand?", "punchline": "A handful of them.", "id": 138}
# Received message: {"type": "general", "setup": "Why do bees have sticky hair?", "punchline": "Because they use honey combs!", "id": 342}
# Received message: {"type": "general", "setup": "How do you know if there\u2019s an elephant under your bed?", "punchline": "Your head hits the ceiling!", "id": 126}
# Received message: {"type": "general", "setup": "Do you know what the word 'was' was initially?", "punchline": "Before was was was was was is.", "id": 36}
# Received message: {"type": "general", "setup": "Two guys walk into a bar . . .", "punchline": "The first guy says \"Ouch!\" and the second says \"Yeah, I didn't see it either.\"", "id": 365}
# Received message: {"type": "general", "setup": "What do you call a careful wolf?", "punchline": "Aware wolf.", "id": 194}
# Received message: {"type": "knock-knock", "setup": "Knock knock. \n Who's there? \n Opportunity.", "punchline": "That is impossible. Opportunity doesn\u2019t come knocking twice!", "id": 33}
# Received message: {"type": "general", "setup": "Did you hear about the runner who was criticized?", "punchline": "He just took it in stride", "id": 93}
# Received message: {"type": "general", "setup": "What do I look like?", "punchline": "A JOKE MACHINE!?", "id": 188}
# Received message: {"type": "programming", "setup": "Why do programmers prefer dark chocolate?", "punchline": "Because it's bitter like their code.", "id": 416}
# Received message: {"type": "general", "setup": "Why don't scientists trust atoms?", "punchline": "Because they make up everything.", "id": 429}
# Received message: {"type": "programming", "setup": "Lady: How do I spread love in this cruel world?", "punchline": "Random Dude: [...\ud83d\udc98]", "id": 58}
# Received message: {"type": "general", "setup": "You see, mountains aren't just funny.", "punchline": "They are hill areas.", "id": 400}
# Received message: {"type": "general", "setup": "What's the best thing about Switzerland?", "punchline": "I don't know, but their flag is a big plus.", "id": 426}
# Received message: {"type": "general", "setup": "What do you give a sick lemon?", "punchline": "Lemonaid.", "id": 233}
# Received message: {"type": "general", "setup": "What did the ocean say to the beach?", "punchline": "Thanks for all the sediment.", "id": 178}
# Received message: {"type": "general", "setup": "What creature is smarter than a talking parrot?", "punchline": "A spelling bee.", "id": 157}
# Received message: {"type": "general", "setup": "Why did the cookie cry?", "punchline": "It was feeling crumby.", "id": 321}
# Received message: {"type": "programming", "setup": "An IPv6 packet is walking out of the house.", "punchline": "He goes nowhere.", "id": 367}
# Received message: {"type": "general", "setup": "Why did the tomato blush?", "punchline": "Because it saw the salad dressing.", "id": 334}
# Received message: {"type": "general", "setup": "I dropped a pear in my car this morning.", "punchline": "You should drop another one, then you would have a pair.", "id": 57}
# Received message: {"type": "general", "setup": "Why did the melons plan a big wedding?", "punchline": "Because they cantaloupe!", "id": 330}
# Received message: {"type": "general", "setup": "Why do choirs keep buckets handy?", "punchline": "So they can carry their tune", "id": 345}
# Received message: {"type": "general", "setup": "What did the dog say to the two trees?", "punchline": "Bark bark.", "id": 170}
# Received message: {"type": "general", "setup": "Did you hear about the guy who invented Lifesavers?", "punchline": "They say he made a mint.", "id": 88}
# Received message: {"type": "general", "setup": "what do you call a dog that can do magic tricks?", "punchline": "a labracadabrador", "id": 200}
# Received message: {"type": "general", "setup": "Dad, can you put my shoes on?", "punchline": "I don't think they'll fit me.", "id": 83}
# Received message: {"type": "general", "setup": "What does C.S. Lewis keep at the back of his wardrobe?", "punchline": "Narnia business!", "id": 22}
# Received message: {"type": "general", "setup": "Why does Waldo only wear stripes?", "punchline": "Because he doesn't want to be spotted.", "id": 388}
# Received message: {"type": "general", "setup": "How does the moon cut his hair?", "punchline": "Eclipse it.", "id": 136}
# Received message: {"type": "programming", "setup": "Why did the programmer's wife leave him?", "punchline": "He didn't know how to commit.", "id": 415}
# Received message: {"type": "general", "setup": "How come a man driving a train got struck by lightning?", "punchline": "He was a good conductor.", "id": 114}
# Received message: {"type": "general", "setup": "Which side of the chicken has more feathers?", "punchline": "The outside.", "id": 295}
# Received message: {"type": "general", "setup": "What did the Red light say to the Green light?", "punchline": "Don't look at me I'm changing!", "id": 182}
# Received message: {"type": "general", "setup": "How does a scientist freshen their breath?", "punchline": "With experi-mints!", "id": 135}
# Received message: {"type": "general", "setup": "Where was the Declaration of Independence signed?", "punchline": "At the bottom! ", "id": 293}
# Received message: {"type": "programming", "setup": "Why did the programmer quit his job?", "punchline": "Because he didn't get arrays.", "id": 18}
# Received message: {"type": "general", "setup": "How does a train eat?", "punchline": "It goes chew, chew", "id": 6}
# Received message: {"type": "knock-knock", "setup": "Knock knock. \n Who's there? \n Hatch. \n Hatch who?", "punchline": "Bless you!", "id": 60}
# Received message: {"type": "general", "setup": "What did the shy pebble wish for?", "punchline": "That she was a little boulder.", "id": 184}
# Received message: {"type": "general", "setup": "Finally realized why my plant sits around doing nothing all day...", "punchline": "He loves his pot.", "id": 45}
# Received message: {"type": "general", "setup": "Where does Napoleon keep his armies?", "punchline": "In his sleevies.", "id": 292}
# Received message: {"type": "general", "setup": "What do you call a cow with two legs?", "punchline": "Lean beef.", "id": 196}
# Received message: {"type": "general", "setup": "What\u2019s 50 Cent\u2019s name in Zimbabwe?", "punchline": "200 Dollars.", "id": 149}
# Received message: {"type": "general", "setup": "When a dad drives past a graveyard: Did you know that's a popular cemetery?", "punchline": "Yep, people are just dying to get in there", "id": 50}
# Received message: {"type": "general", "setup": "What do you call a crowd of chess players bragging about their wins in a hotel lobby?", "punchline": "Chess nuts boasting in an open foyer.", "id": 197}
# Received message: {"type": "general", "setup": "What did the traffic light say to the car as it passed?", "punchline": "Don't look I'm changing!", "id": 185}
# Received message: {"type": "dad", "setup": "Why do fathers take an extra pair of socks when they go golfing?", "punchline": "In case they get a hole in one!", "id": 378}
# Received message: {"type": "programming", "setup": "Why do Java programmers wear glasses?", "punchline": "Because they don't C#.", "id": 34}
