# %%
import requests
import time
from confluent_kafka import Producer
import json

producer_conf = {
    'bootstrap.servers': 'localhost:9092'  # Kafka server address
}

producer = Producer(producer_conf)

topic = 'test1-topic'

# Function to handle delivery reports (optional)
def delivery_report(err, msg):
    if err is not None:
        print(f"Delivery failed for record {msg.key()}: {err}")
    else:
        print(f"Record successfully produced to {msg.topic()} [{msg.partition()}] at offset {msg.offset()}")

# Function to get data from the real-time API
def fetch_data_from_api():
    url = "https://official-joke-api.appspot.com/random_joke"
    response = requests.get(url)
    
    if response.status_code == 200:
        return response.json()  # Return the data as a JSON object
    else:
        print(f"Error: Unable to fetch data (Status code: {response.status_code})")
        return None

try:
    while True:
        data = fetch_data_from_api()
        
        if data:
            message_value = json.dumps(data)
            
            producer.produce(topic, key=None, value=message_value, callback=delivery_report)
            
            producer.flush()
            
            print(f"Sent data to Kafka: {message_value}")
        
        time.sleep(5)

except KeyboardInterrupt:
    print("Producer interrupted")

finally:
    producer.flush()
    print("Finished streaming data.")
# Out:
# Record successfully produced to test1-topic [0] at offset 385
# Sent data to Kafka: {"type": "general", "setup": "What do you call a factory that sells passable products?", "punchline": "A satisfactory", "id": 49}
# Record successfully produced to test1-topic [0] at offset 386
# Sent data to Kafka: {"type": "general", "setup": "Did you hear about the scientist who was lab partners with a pot of boiling water?", "punchline": "He had a very esteemed colleague.", "id": 94}
# Record successfully produced to test1-topic [0] at offset 387
# Sent data to Kafka: {"type": "programming", "setup": "Where do programmers like to hangout?", "punchline": "The Foo Bar.", "id": 17}
# Record successfully produced to test1-topic [0] at offset 388
# Sent data to Kafka: {"type": "general", "setup": "Why did the invisible man turn down the job offer?", "punchline": "He couldn't see himself doing it", "id": 51}
# Record successfully produced to test1-topic [0] at offset 389
# Sent data to Kafka: {"type": "general", "setup": "What do you call a monkey in a mine field?", "punchline": "A babooooom!", "id": 210}
# Record successfully produced to test1-topic [0] at offset 390
# Sent data to Kafka: {"type": "general", "setup": "What biscuit does a short person like?", "punchline": "Shortbread. ", "id": 155}
# Record successfully produced to test1-topic [0] at offset 391
# Sent data to Kafka: {"type": "general", "setup": "Why do crabs never give to charity?", "punchline": "Because they\u2019re shellfish.", "id": 346}
# Record successfully produced to test1-topic [0] at offset 392
# Sent data to Kafka: {"type": "general", "setup": "Did you hear about the runner who was criticized?", "punchline": "He just took it in stride", "id": 93}
# Record successfully produced to test1-topic [0] at offset 393
# Sent data to Kafka: {"type": "general", "setup": "What did Michael Jackson name his denim store?", "punchline": "Billy Jeans!", "id": 159}
# Record successfully produced to test1-topic [0] at offset 394
# Sent data to Kafka: {"type": "general", "setup": "How good are you at Power Point?", "punchline": "I Excel at it.", "id": 128}
# Record successfully produced to test1-topic [0] at offset 395
# Sent data to Kafka: {"type": "general", "setup": "What did the pirate say on his 80th birthday?", "punchline": "Aye Matey!", "id": 181}
# Record successfully produced to test1-topic [0] at offset 396
# Sent data to Kafka: {"type": "programming", "setup": "Where did the API go to eat?", "punchline": "To the RESTaurant.", "id": 390}
# Record successfully produced to test1-topic [0] at offset 397
# Sent data to Kafka: {"type": "general", "setup": "How was the snow globe feeling after the storm?", "punchline": "A little shaken.", "id": 145}
# Record successfully produced to test1-topic [0] at offset 398
# Sent data to Kafka: {"type": "general", "setup": "How many kids with ADD does it take to change a lightbulb?", "punchline": "Let's go ride bikes!", "id": 140}
# Record successfully produced to test1-topic [0] at offset 399
# Sent data to Kafka: {"type": "general", "setup": "How many bones are in the human hand?", "punchline": "A handful of them.", "id": 138}
# Record successfully produced to test1-topic [0] at offset 400
# Sent data to Kafka: {"type": "general", "setup": "Why do bees have sticky hair?", "punchline": "Because they use honey combs!", "id": 342}
# Record successfully produced to test1-topic [0] at offset 401
# Sent data to Kafka: {"type": "general", "setup": "How do you know if there\u2019s an elephant under your bed?", "punchline": "Your head hits the ceiling!", "id": 126}
# Record successfully produced to test1-topic [0] at offset 402
# Sent data to Kafka: {"type": "general", "setup": "Do you know what the word 'was' was initially?", "punchline": "Before was was was was was is.", "id": 36}
# Record successfully produced to test1-topic [0] at offset 403
# Sent data to Kafka: {"type": "general", "setup": "Two guys walk into a bar . . .", "punchline": "The first guy says \"Ouch!\" and the second says \"Yeah, I didn't see it either.\"", "id": 365}
# Record successfully produced to test1-topic [0] at offset 404
# Sent data to Kafka: {"type": "general", "setup": "What do you call a careful wolf?", "punchline": "Aware wolf.", "id": 194}
# Record successfully produced to test1-topic [0] at offset 405
# Sent data to Kafka: {"type": "knock-knock", "setup": "Knock knock. \n Who's there? \n Opportunity.", "punchline": "That is impossible. Opportunity doesn\u2019t come knocking twice!", "id": 33}
# Record successfully produced to test1-topic [0] at offset 406
# Sent data to Kafka: {"type": "general", "setup": "Did you hear about the runner who was criticized?", "punchline": "He just took it in stride", "id": 93}
# Record successfully produced to test1-topic [0] at offset 407
# Sent data to Kafka: {"type": "general", "setup": "What do I look like?", "punchline": "A JOKE MACHINE!?", "id": 188}
# Record successfully produced to test1-topic [0] at offset 408
# Sent data to Kafka: {"type": "programming", "setup": "Why do programmers prefer dark chocolate?", "punchline": "Because it's bitter like their code.", "id": 416}
# Record successfully produced to test1-topic [0] at offset 409
# Sent data to Kafka: {"type": "general", "setup": "Why don't scientists trust atoms?", "punchline": "Because they make up everything.", "id": 429}
# Record successfully produced to test1-topic [0] at offset 410
# Sent data to Kafka: {"type": "programming", "setup": "Lady: How do I spread love in this cruel world?", "punchline": "Random Dude: [...\ud83d\udc98]", "id": 58}
# Record successfully produced to test1-topic [0] at offset 411
# Sent data to Kafka: {"type": "general", "setup": "You see, mountains aren't just funny.", "punchline": "They are hill areas.", "id": 400}
# Record successfully produced to test1-topic [0] at offset 412
# Sent data to Kafka: {"type": "general", "setup": "What's the best thing about Switzerland?", "punchline": "I don't know, but their flag is a big plus.", "id": 426}
# Record successfully produced to test1-topic [0] at offset 413
# Sent data to Kafka: {"type": "general", "setup": "What do you give a sick lemon?", "punchline": "Lemonaid.", "id": 233}
# Record successfully produced to test1-topic [0] at offset 414
# Sent data to Kafka: {"type": "general", "setup": "What did the ocean say to the beach?", "punchline": "Thanks for all the sediment.", "id": 178}
# Record successfully produced to test1-topic [0] at offset 415
# Sent data to Kafka: {"type": "general", "setup": "What creature is smarter than a talking parrot?", "punchline": "A spelling bee.", "id": 157}
# Record successfully produced to test1-topic [0] at offset 416
# Sent data to Kafka: {"type": "general", "setup": "Why did the cookie cry?", "punchline": "It was feeling crumby.", "id": 321}
# Record successfully produced to test1-topic [0] at offset 417
# Sent data to Kafka: {"type": "programming", "setup": "An IPv6 packet is walking out of the house.", "punchline": "He goes nowhere.", "id": 367}
# Record successfully produced to test1-topic [0] at offset 418
# Sent data to Kafka: {"type": "general", "setup": "Why did the tomato blush?", "punchline": "Because it saw the salad dressing.", "id": 334}
# Record successfully produced to test1-topic [0] at offset 419
# Sent data to Kafka: {"type": "general", "setup": "I dropped a pear in my car this morning.", "punchline": "You should drop another one, then you would have a pair.", "id": 57}
# Record successfully produced to test1-topic [0] at offset 420
# Sent data to Kafka: {"type": "general", "setup": "Why did the melons plan a big wedding?", "punchline": "Because they cantaloupe!", "id": 330}
# Record successfully produced to test1-topic [0] at offset 421
# Sent data to Kafka: {"type": "general", "setup": "Why do choirs keep buckets handy?", "punchline": "So they can carry their tune", "id": 345}
# Record successfully produced to test1-topic [0] at offset 422
# Sent data to Kafka: {"type": "general", "setup": "What did the dog say to the two trees?", "punchline": "Bark bark.", "id": 170}
# Record successfully produced to test1-topic [0] at offset 423
# Sent data to Kafka: {"type": "general", "setup": "Did you hear about the guy who invented Lifesavers?", "punchline": "They say he made a mint.", "id": 88}
# Record successfully produced to test1-topic [0] at offset 424
# Sent data to Kafka: {"type": "general", "setup": "what do you call a dog that can do magic tricks?", "punchline": "a labracadabrador", "id": 200}
# Record successfully produced to test1-topic [0] at offset 425
# Sent data to Kafka: {"type": "general", "setup": "Dad, can you put my shoes on?", "punchline": "I don't think they'll fit me.", "id": 83}
# Record successfully produced to test1-topic [0] at offset 426
# Sent data to Kafka: {"type": "general", "setup": "What does C.S. Lewis keep at the back of his wardrobe?", "punchline": "Narnia business!", "id": 22}
# Record successfully produced to test1-topic [0] at offset 427
# Sent data to Kafka: {"type": "general", "setup": "Why does Waldo only wear stripes?", "punchline": "Because he doesn't want to be spotted.", "id": 388}
# Record successfully produced to test1-topic [0] at offset 428
# Sent data to Kafka: {"type": "general", "setup": "How does the moon cut his hair?", "punchline": "Eclipse it.", "id": 136}
# Record successfully produced to test1-topic [0] at offset 429
# Sent data to Kafka: {"type": "programming", "setup": "Why did the programmer's wife leave him?", "punchline": "He didn't know how to commit.", "id": 415}
# Record successfully produced to test1-topic [0] at offset 430
# Sent data to Kafka: {"type": "general", "setup": "How come a man driving a train got struck by lightning?", "punchline": "He was a good conductor.", "id": 114}
# Record successfully produced to test1-topic [0] at offset 431
# Sent data to Kafka: {"type": "general", "setup": "Which side of the chicken has more feathers?", "punchline": "The outside.", "id": 295}
# Record successfully produced to test1-topic [0] at offset 432
# Sent data to Kafka: {"type": "general", "setup": "What did the Red light say to the Green light?", "punchline": "Don't look at me I'm changing!", "id": 182}
# Record successfully produced to test1-topic [0] at offset 433
# Sent data to Kafka: {"type": "general", "setup": "How does a scientist freshen their breath?", "punchline": "With experi-mints!", "id": 135}
# Record successfully produced to test1-topic [0] at offset 434
# Sent data to Kafka: {"type": "general", "setup": "Where was the Declaration of Independence signed?", "punchline": "At the bottom! ", "id": 293}
# Record successfully produced to test1-topic [0] at offset 435
# Sent data to Kafka: {"type": "programming", "setup": "Why did the programmer quit his job?", "punchline": "Because he didn't get arrays.", "id": 18}
# Record successfully produced to test1-topic [0] at offset 436
# Sent data to Kafka: {"type": "general", "setup": "How does a train eat?", "punchline": "It goes chew, chew", "id": 6}
# Record successfully produced to test1-topic [0] at offset 437
# Sent data to Kafka: {"type": "knock-knock", "setup": "Knock knock. \n Who's there? \n Hatch. \n Hatch who?", "punchline": "Bless you!", "id": 60}
# Record successfully produced to test1-topic [0] at offset 438
# Sent data to Kafka: {"type": "general", "setup": "What did the shy pebble wish for?", "punchline": "That she was a little boulder.", "id": 184}
# Record successfully produced to test1-topic [0] at offset 439
# Sent data to Kafka: {"type": "general", "setup": "Finally realized why my plant sits around doing nothing all day...", "punchline": "He loves his pot.", "id": 45}
# Record successfully produced to test1-topic [0] at offset 440
# Sent data to Kafka: {"type": "general", "setup": "Where does Napoleon keep his armies?", "punchline": "In his sleevies.", "id": 292}
# Record successfully produced to test1-topic [0] at offset 441
# Sent data to Kafka: {"type": "general", "setup": "What do you call a cow with two legs?", "punchline": "Lean beef.", "id": 196}
# Record successfully produced to test1-topic [0] at offset 442
# Sent data to Kafka: {"type": "general", "setup": "What\u2019s 50 Cent\u2019s name in Zimbabwe?", "punchline": "200 Dollars.", "id": 149}
# Record successfully produced to test1-topic [0] at offset 443
# Sent data to Kafka: {"type": "general", "setup": "When a dad drives past a graveyard: Did you know that's a popular cemetery?", "punchline": "Yep, people are just dying to get in there", "id": 50}
# Record successfully produced to test1-topic [0] at offset 444
# Sent data to Kafka: {"type": "general", "setup": "What do you call a crowd of chess players bragging about their wins in a hotel lobby?", "punchline": "Chess nuts boasting in an open foyer.", "id": 197}
# Record successfully produced to test1-topic [0] at offset 445
# Sent data to Kafka: {"type": "general", "setup": "What did the traffic light say to the car as it passed?", "punchline": "Don't look I'm changing!", "id": 185}
# Record successfully produced to test1-topic [0] at offset 446
# Sent data to Kafka: {"type": "dad", "setup": "Why do fathers take an extra pair of socks when they go golfing?", "punchline": "In case they get a hole in one!", "id": 378}
